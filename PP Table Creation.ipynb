# %%
import os
import pandas as pd
import json

# %%
# Aggregated Transaction
path1 = "C:/Users/admin/Desktop/Guvi-Data Science/Streamlit/pulse/data/aggregated/transaction/country/india/state/"
agg_state_list = os.listdir(path1)

data_dict3 = {'State': [], 'Year': [], 'Quater': [], 'Transaction_type': [], 'Transaction_count': [], 'Transaction_amount': []}

transactions = [d for d in agg_state_list if os.path.isdir(os.path.join(path1, d))]

for state in transactions:
    state_path = os.path.join(path1, state)
    years = [os.path.join(state_path, y) for y in os.listdir(state_path) if os.path.isdir(os.path.join(state_path, y))]

    for year_path in years:
        files = [os.path.join(year_path, f) for f in os.listdir(year_path) if os.path.isfile(os.path.join(year_path, f))]

        for file_path in files:
            with open(file_path, 'r') as data_file:
                A= json.load(data_file)
                for item in A['data']['transactionData']: 
                    trans_type = item['name']
                    trans_count = item['paymentInstruments'][0]['count']
                    trans_amount = item['paymentInstruments'][0]['amount']
                    data_dict3['Transaction_type'].append(trans_type)
                    data_dict3['Transaction_count'].append(trans_count)
                    data_dict3['Transaction_amount'].append(trans_amount)
                    data_dict3['State'].append(state)
                    data_dict3['Year'].append(os.path.basename(year_path))
                    data_dict3['Quater'].append(int(os.path.splitext(os.path.basename(file_path))[0]))

# Successfully created a DataFrame
agg_transaction_df = pd.DataFrame(data_dict3)
agg_transaction_df
# Out:
#                           State  Year  Quater          Transaction_type  \
# 0     andaman-&-nicobar-islands  2018       1  Recharge & bill payments
# 1     andaman-&-nicobar-islands  2018       1     Peer-to-peer payments
# 2     andaman-&-nicobar-islands  2018       1         Merchant payments
# 3     andaman-&-nicobar-islands  2018       1        Financial Services
# 4     andaman-&-nicobar-islands  2018       1                    Others
# ...                         ...   ...     ...                       ...
# 4309                west-bengal  2023       4         Merchant payments
# 4310                west-bengal  2023       4     Peer-to-peer payments
# 4311                west-bengal  2023       4  Recharge & bill payments
# 4312                west-bengal  2023       4        Financial Services
# 4313                west-bengal  2023       4                    Others
#
#       Transaction_count  Transaction_amount
# 0                  4200        1.845307e+06
# ...

# %%
# Aggregated User
path2 = "C:/Users/admin/Desktop/Guvi-Data Science/Streamlit/pulse/data/aggregated/user/country/india/state/"
agg_state_list = os.listdir(path2)

data_dict3 = {'State': [], 'Year': [], 'Quater': [], 'Brands': [], 'Transaction_count': [], 'Percentage': []}

transactions = [d for d in agg_state_list if os.path.isdir(os.path.join(path1, d))]

for state in transactions:
    state_path = os.path.join(path2, state)
    years = [os.path.join(state_path, y) for y in os.listdir(state_path) if os.path.isdir(os.path.join(state_path, y))]

    for year_path in years:
        files = [os.path.join(year_path, f) for f in os.listdir(year_path) if os.path.isfile(os.path.join(year_path, f))]

        for file_path in files:
            with open(file_path, 'r') as data_file:
                B = json.load(data_file)

                users_by_device_data = B.get('data', {}).get('usersByDevice')
                
                # Check if users_by_device_data is None before iterating
                if users_by_device_data is not None:
                    for item in users_by_device_data:
                        brand = item.get("brand", '')
                        count = item.get("count", 0)
                        percentage = item.get("percentage", 0)

                        data_dict3["Brands"].append(brand)
                        data_dict3["Transaction_count"].append(count)
                        data_dict3["Percentage"].append(percentage)
                        data_dict3['State'].append(state)
                        data_dict3['Year'].append(os.path.basename(year_path))
                        data_dict3['Quater'].append(int(os.path.splitext(os.path.basename(file_path))[0]))

# Successfully created a DataFrame
agg_transaction_df = pd.DataFrame(data_dict3)
agg_transaction_df
# Out:
#                           State  Year  Quater   Brands  Transaction_count  \
# 0     andaman-&-nicobar-islands  2018       1   Xiaomi               1665
# 1     andaman-&-nicobar-islands  2018       1  Samsung               1445
# 2     andaman-&-nicobar-islands  2018       1     Vivo                982
# 3     andaman-&-nicobar-islands  2018       1     Oppo                501
# 4     andaman-&-nicobar-islands  2018       1  OnePlus                332
# ...                         ...   ...     ...      ...                ...
# 6727                west-bengal  2022       1   Lenovo             330017
# 6728                west-bengal  2022       1  Infinix             284678
# 6729                west-bengal  2022       1     Asus             280347
# 6730                west-bengal  2022       1    Apple             277752
# 6731                west-bengal  2022       1   Others            2196334
#
#       Percentage
# 0       0.247033
# 1       0.214392
# 2       0.145697
# ...

# %%
# Aggregated Insurance
path_insurance = "C:/Users/admin/Desktop/Guvi-Data Science/Streamlit/pulse/data/map/insurance/country/india/state"
agg_insurance_state_list = os.listdir(path_insurance)

data_dict_insurance = {'State': [], 'Year': [], 'Quater': [], 'Brands': [], 'Transaction_count': [], 'Percentage': []}

insurance_transactions = [d for d in agg_insurance_state_list if os.path.isdir(os.path.join(path_insurance, d))]

for state in insurance_transactions:
    state_path = os.path.join(path_insurance, state)
    years = [os.path.join(state_path, y) for y in os.listdir(state_path) if os.path.isdir(os.path.join(state_path, y))]

    for year_path in years:
        files = [os.path.join(year_path, f) for f in os.listdir(year_path) if os.path.isfile(os.path.join(year_path, f))]

        for file_path in files:
            with open(file_path, 'r') as data_file:
                insurance_data = json.load(data_file)

                # Modify the code to extract information based on the actual structure of insurance_data
                # This is a generic template, and you may need to adjust it based on the actual keys in your JSON data
                lat_lng_data = insurance_data.get('data', {}).get('data', [])

                for item in lat_lng_data:
                    lat = item[0]
                    lng = item[1]
                    metric = item[2]
                    label = item[3]

                    # Add your logic to extract information about brands, transaction count, and percentage
                    # For now, I'll just use placeholders
                    brand = "ExampleBrand"
                    count = 100
                    percentage = 10.0

                    data_dict_insurance["Brands"].append(brand)
                    data_dict_insurance["Transaction_count"].append(count)
                    data_dict_insurance["Percentage"].append(percentage)
                    data_dict_insurance['State'].append(state)
                    data_dict_insurance['Year'].append(os.path.basename(year_path))
                    data_dict_insurance['Quater'].append(int(os.path.splitext(os.path.basename(file_path))[0]))

# Successfully created a DataFrame
agg_insurance_df = pd.DataFrame(data_dict_insurance)
agg_insurance_df
# Out:
#                           State  Year  Quater        Brands  \
# 0     andaman-&-nicobar-islands  2020       2  ExampleBrand
# 1     andaman-&-nicobar-islands  2020       2  ExampleBrand
# 2     andaman-&-nicobar-islands  2020       3  ExampleBrand
# 3     andaman-&-nicobar-islands  2020       3  ExampleBrand
# 4     andaman-&-nicobar-islands  2020       4  ExampleBrand
# ...                         ...   ...     ...           ...
# 1075                west-bengal  2023       2  ExampleBrand
# 1076                west-bengal  2023       3  ExampleBrand
# 1077                west-bengal  2023       3  ExampleBrand
# 1078                west-bengal  2023       4  ExampleBrand
# 1079                west-bengal  2023       4  ExampleBrand
#
#       Transaction_count  Percentage
# 0                   100        10.0
# 1                   100        10.0
# 2                   100        10.0
# 3                   100        10.0
# 4                   100        10.0
# ...

# %%
# Map Transaction 
path3 = "C:/Users/admin/Desktop/Guvi-Data Science/Streamlit/pulse/data/map/transaction/hover/country/india/state/"
map_hover_state_list = os.listdir(path3)

data_dict_map_hover_transaction = {'State': [], 'Year': [], 'Quater': [], 'Transaction_type': [], 'Transaction_count': [], 'Transaction_amount': []}

map_hover_transactions = [d for d in map_hover_state_list if os.path.isdir(os.path.join(path3, d))]

for state in map_hover_transactions:
    state_path = os.path.join(path3, state)
    years = [os.path.join(state_path, y) for y in os.listdir(state_path) if os.path.isdir(os.path.join(state_path, y))]

    for year_path in years:
        files = [os.path.join(year_path, f) for f in os.listdir(year_path) if os.path.isfile(os.path.join(year_path, f))]

        for file_path in files:
            with open(file_path, 'r') as data_file:
                map_hover_data = json.load(data_file)
                for item in map_hover_data['data']['hoverDataList']:
                    for metric in item['metric']:
                        trans_type = f"{item['name']} - {metric['type']}"
                        trans_count = metric['count']
                        trans_amount = metric['amount']
                        data_dict_map_hover_transaction['Transaction_type'].append(trans_type)
                        data_dict_map_hover_transaction['Transaction_count'].append(trans_count)
                        data_dict_map_hover_transaction['Transaction_amount'].append(trans_amount)
                        data_dict_map_hover_transaction['State'].append(state)
                        data_dict_map_hover_transaction['Year'].append(os.path.basename(year_path))
                        data_dict_map_hover_transaction['Quater'].append(int(os.path.splitext(os.path.basename(file_path))[0]))

# Successfully created a DataFrame
map_hover_transaction_df = pd.DataFrame(data_dict_map_hover_transaction)
map_hover_transaction_df
# Out:
#                            State  Year  Quater  \
# 0      andaman-&-nicobar-islands  2018       1
# 1      andaman-&-nicobar-islands  2018       1
# 2      andaman-&-nicobar-islands  2018       1
# 3      andaman-&-nicobar-islands  2018       2
# 4      andaman-&-nicobar-islands  2018       2
# ...                          ...   ...     ...
# 17559                west-bengal  2023       4
# 17560                west-bengal  2023       4
# 17561                west-bengal  2023       4
# 17562                west-bengal  2023       4
# 17563                west-bengal  2023       4
#
#                                 Transaction_type  Transaction_count  \
# 0      north and middle andaman district - TOTAL                442
# 1                 south andaman district - TOTAL               5688
# 2                      nicobars district - TOTAL                528
# 3      north and middle andaman district - TOTAL                825
# ...

# %%
# Map User 
path_map_user_hover = "C:/Users/admin/Desktop/Guvi-Data Science/Streamlit/pulse/data/map/user/hover/country/india/state/"
map_user_hover_state_list = os.listdir(path_map_user_hover)

data_dict_map_user_hover = {'State': [], 'Year': [], 'Quater': [], 'District': [], 'RegisteredUsers': [], 'AppOpens': []}


map_user_hover_states = [d for d in map_user_hover_state_list if os.path.isdir(os.path.join(path_map_user_hover, d))]

for state in map_user_hover_states:
    state_path = os.path.join(path_map_user_hover, state)
    years = [os.path.join(state_path, y) for y in os.listdir(state_path) if os.path.isdir(os.path.join(state_path, y))]

    for year_path in years:
        files = [os.path.join(year_path, f) for f in os.listdir(year_path) if os.path.isfile(os.path.join(year_path, f))]

        for file_path in files:
            with open(file_path, 'r') as data_file:
                map_user_hover_data = json.load(data_file)
                
                # Check if 'data' key exists, and then access 'hoverData'
                if 'data' in map_user_hover_data and 'hoverData' in map_user_hover_data['data']:
                    hover_data = map_user_hover_data['data']['hoverData']
                    
                    for district, district_data in hover_data.items():
                        registered_users = district_data.get('registeredUsers', 0)
                        app_opens = district_data.get('appOpens', 0)
                        
                        # Add your logic to process the data as needed
                        # For example, you can add this information to your DataFrame
                        data_dict_map_user_hover['State'].append(state)
                        data_dict_map_user_hover['Year'].append(os.path.basename(year_path))
                        data_dict_map_user_hover['Quater'].append(int(os.path.splitext(os.path.basename(file_path))[0]))
                        data_dict_map_user_hover['District'].append(district)
                        data_dict_map_user_hover['RegisteredUsers'].append(registered_users)
                        data_dict_map_user_hover['AppOpens'].append(app_opens)

# Successfully created a DataFrame
map_user_hover_df = pd.DataFrame(data_dict_map_user_hover)
map_user_hover_df
# Out:
#                            State  Year  Quater  \
# 0      andaman-&-nicobar-islands  2018       1
# 1      andaman-&-nicobar-islands  2018       1
# 2      andaman-&-nicobar-islands  2018       1
# 3      andaman-&-nicobar-islands  2018       2
# 4      andaman-&-nicobar-islands  2018       2
# ...                          ...   ...     ...
# 17563                west-bengal  2023       4
# 17564                west-bengal  2023       4
# 17565                west-bengal  2023       4
# 17566                west-bengal  2023       4
# 17567                west-bengal  2023       4
#
#                                 District  RegisteredUsers  AppOpens
# 0      north and middle andaman district              632         0
# 1                 south andaman district             5846         0
# 2                      nicobars district              262         0
# 3      north and middle andaman district              911         0
# ...
